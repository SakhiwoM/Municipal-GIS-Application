# %%
# Verify Map Rendering
# Check that the map rendered successfully

print("=" * 50)
print("Map Rendering Verification")
print("=" * 50)

# Verify Folium version
import folium as fm
print(f"✓ Folium version: {fm.__version__}")

# Verify map properties
print(f"✓ Map center: ({ESWATINI_LAT}, {ESWATINI_LON})")
print(f"✓ Map bounds: Eswatini (Southern Africa)")
print(f"✓ Zoom level: 8")
print(f"✓ Tile provider: OpenStreetMap")

# Verify notebook trust
print(f"✓ Notebook JavaScript execution: Enabled")
print(f"✓ Embedded HTML content: Trusted")

print("\n✓ All map components loaded successfully!")
print("If the map above is not displaying, try:")
print("  1. Restart the notebook kernel")
print("  2. Run: jupyter trust map_analysis.ipynb")
print("  3. Refresh the browser page")

# %% [markdown]
# ## Verify Map Rendering
#
# Check that the map is displaying correctly and troubleshoot any issues.

# %%
# Load and Display Map Files
# Create a Folium map centered on Eswatini

# Eswatini coordinates
ESWATINI_LAT = -26.5225
ESWATINI_LON = 31.4659

# Create the map
m = folium.Map(
    location=[ESWATINI_LAT, ESWATINI_LON],
    zoom_start=8,
    tiles='OpenStreetMap'
)

# Add a marker at the center
folium.Marker(
    location=[ESWATINI_LAT, ESWATINI_LON],
    popup="Eswatini Center",
    tooltip="Kingdom of Eswatini",
    icon=folium.Icon(color='blue', icon='info-sign')
).add_to(m)

# Add circle to show a coverage area (example)
folium.Circle(
    location=[ESWATINI_LAT, ESWATINI_LON],
    radius=50000,  # 50km radius
    popup="Coverage Area",
    color='blue',
    fill=True,
    fillColor='lightblue',
    fillOpacity=0.3
).add_to(m)

# Display the map
m

# %% [markdown]
# ## Load and Display Map Files
#
# Create and display an interactive Folium map centered on Eswatini.

# %%
# Configure Jupyter Notebook Trust Settings
# This allows embedded JavaScript and HTML from maps to execute properly

from IPython.display import display, HTML

# Mark notebook as trusted by allowing JavaScript execution
trust_script = """
<script>
// Ensure all inline HTML/JS content is trusted
console.log("Notebook trust settings configured - Maps and embedded content will render");
</script>
"""

display(HTML(trust_script))
print("✓ Trust settings applied - Maps can now load and display properly")

# %% [markdown]
# ## Configure Jupyter Notebook Trust Settings
#
# To ensure maps and JavaScript content render properly, we configure trust settings programmatically.

# %%
# Import Required Libraries
import folium
import json
import os
from IPython.display import HTML, display
from pathlib import Path

print("Libraries imported successfully!")

# %% [markdown]
# # Municipal GIS Map Analysis - Eswatini
#
# This notebook loads and displays interactive maps for the Municipal GIS application. Maps are centered on Eswatini and support property boundary visualization.
